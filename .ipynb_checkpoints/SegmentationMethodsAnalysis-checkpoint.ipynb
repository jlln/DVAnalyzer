# %%
import pandas
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
# %matplotlib inline
import numpy as np

# %%
seg_data = pandas.read_csv("segmentation_comparison2.txt")

# %%
seg_data.head()
# Out:
#     b    f   n  five_means_ce  five_means_pe  four_means_ce  four_means_pe  \
# 0  22  199  22              1      -6.547170       0.043726       0.002432
# 1   4  190  20              1      -7.297990       0.035917       0.001752
# 2   1  152   6              1      -8.003601       0.000000       0.000000
# 3  45  147  21              1      -6.629705       0.051867       0.018396
# 4  46  190   9              1      -6.923233       0.007890       0.000352
#
#    three_means_ce  three_means_pe  two_means_ce  two_means_pe    SCT_ce  \
# 0       -4.349810       -6.172914     -4.296578     -6.179287 -3.207224
# 1       -2.739130       -4.644662     -2.863894     -4.671676 -2.788280
# 2       -0.235867       -4.191477     -0.532164     -4.345738  0.124756
# 3        0.939834       -6.627247      0.941909     -6.627331 -6.232365
# 4        1.000000       -6.923233      1.000000     -6.923233  0.071006
#
#      SCT_pe
# 0 -0.653585
# 1 -0.700074
# 2 -0.431773
# 3 -1.311885
# 4 -0.385333

# %%
seg_data["snr"] = (seg_data.f - seg_data.b)/seg_data.n

# %%
segm = pandas.melt(seg_data,id_vars=["b","f","n","snr"])

# %%
segm['Error Type'] = ["Foreground Pixel Count Error" if "pe" in x else "Object Count Error" for x in segm.variable.values ]
segm['Segmentation Method'] = [x[:-3] for x in segm.variable.values]
segm["Signal to Noise Ratio"] =segm.snr
segm["Error Rate"] = segm.value

# %%
segm["Absolute Fold Error"] = np.abs(segm.value)
segm["Fold Error"] = segm.value

# %%
segm.head()
# Out:
#     b    f   n        snr       variable  value          Error Type  \
# 0  22  199  22   8.045455  five_means_ce      1  Object Count Error
# 1   4  190  20   9.300000  five_means_ce      1  Object Count Error
# 2   1  152   6  25.166667  five_means_ce      1  Object Count Error
# 3  45  147  21   4.857143  five_means_ce      1  Object Count Error
# 4  46  190   9  16.000000  five_means_ce      1  Object Count Error
#
#   Segmentation Method  Signal to Noise Ratio  Error Rate  Absolute Fold Error  \
# 0          five_means               8.045455           1                    1
# 1          five_means               9.300000           1                    1
# 2          five_means              25.166667           1                    1
# 3          five_means               4.857143           1                    1
# 4          five_means              16.000000           1                    1
#
#    Fold Error
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
sns.set_style("whitegrid")
sns.set_palette("Set1",2)
grid = sns.FacetGrid(segm,col="Error Type", row="Segmentation Method", size=5,sharey=False,xlim=(-1,50))
grid.map(plt.scatter, "Signal to Noise Ratio", "Fold Error",s=15)
grid.set_titles(col_template="{col_name} ", fontweight='bold', fontsize=8)

# %%
four_means_sct = segm[(segm["Segmentation Method"]=="SCT")|(segm["Segmentation Method"]=="four_means")]

# %%
sns.set_style("whitegrid")
sns.set_palette("Set1",2)
grid = sns.FacetGrid(four_means_sct,row="Error Type", col="Segmentation Method", size=5,sharey=False,xlim=(-1,50))
grid.map(plt.scatter, "Signal to Noise Ratio", "Fold Error",s=15)
grid.set_titles(col_template="{col_name} ", fontweight='bold', fontsize=8)
